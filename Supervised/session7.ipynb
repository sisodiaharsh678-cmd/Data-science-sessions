# %%
import numpy as np 
from sklearn.metrics import mean_squared_error 

actual_time    = np.array([30, 45, 20, 60, 35, 50, 25, 40, 55, 15])
predicted_time = np.array([28, 48, 22, 57, 38, 53, 24, 43, 50, 18])

mse = mean_squared_error(actual_time , predicted_time)
rmse = np.sqrt(mse)

print("Actual    :", actual_time)
print("Predicted :", predicted_time)
print(f"\nMSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
# Out:
# Actual    : [30 45 20 60 35 50 25 40 55 15]
# Predicted : [28 48 22 57 38 53 24 43 50 18]
#
# MSE  : 8.8000
# RMSE : 2.9665

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score

actual_price    = np.array([999, 1499, 2999, 599, 4999, 799, 1999, 3499, 699, 2499])
predicted_price = np.array([950, 1550, 2900, 620, 5100, 780, 2050, 3400, 720, 2550])

mse = mean_squared_error(actual_price , predicted_price)
rmse = np.sqrt(mse)
r2= r2_score(actual_price , predicted_price)

print("Actual    :", actual_time)
print("Predicted :", predicted_time)
print(f"\nMSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R2 : {r2:.4f}")
# Out:
# Actual    : [30 45 20 60 35 50 25 40 55 15]
# Predicted : [28 48 22 57 38 53 24 43 50 18]
#
# MSE  : 4125.0000
# RMSE : 64.2262
# R2 : 0.9978

# %%
models = {
    'Model A': {'RMSE': 8, 'R2': 0.65},
    'Model B': {'RMSE': 6, 'R2': 0.55},
}

print("""
Which model to choose? → MODEL A 

Reasoning:
  RMSE (6 vs 8):
    Model B has lower RMSE — predictions are off by only 6 min vs 8 min.
    Lower RMSE = more accurate predictions in absolute terms.

  R² (0.65 vs 0.55):
    Model A has higher R² — explains 65% of delivery time variance.
    Model B only explains 55% — misses more patterns in data.

  Final Decision → MODEL A:
    R² matters more here — it tells how well the model understands
    the relationship between features and delivery time.
    Model B may be accurate on average but misses key patterns.
    For real-world delivery prediction, understanding variance is crucial.
""")

# %%
import pandas as pd 
import numpy as np
from  sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


df = pd.read_csv("spotify_top50.csv" , encoding="latin1")
df.head(2)

X = df.select_dtypes(include=['number']).drop(columns=['Popularity'])
y = df['Popularity']
X_train , X_test , y_train , y_test = train_test_split(
    X , y , test_size=0.1 , random_state=42
)

#model-A 
modelA = LinearRegression()
modelA.fit(X_train , y_train)

# Model B - Decision Tree
modelB = DecisionTreeRegressor(random_state=42)
modelB.fit(X_train, y_train)


def evaluate(model , name):
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    print(f"\n{name}")
    print(f"  MSE   : {mean_squared_error(y_test, test_pred):.2f}")
    print(f"  RMSE  : {np.sqrt(mean_squared_error(y_test, test_pred)):.2f}")
    print(f"  MAE   : {mean_absolute_error(y_test, test_pred):.2f}")
    print(f"  Train R² : {r2_score(y_train, train_pred):.2f}")
    print(f"  Test  R² : {r2_score(y_test,  test_pred):.2f}")

evaluate(modelA , "modelA = linear regression") 
evaluate(modelB , "modelB = decision tree")
# Out:
# modelA = linear regression
#   MSE   : 28.01
#   RMSE  : 5.29
#   MAE   : 4.72
#   Train R² : 0.24
#   Test  R² : -0.44
#
# modelB = decision tree
#   MSE   : 129.60
#   RMSE  : 11.38
#   MAE   : 8.80
#   Train R² : 1.00
#   Test  R² : -5.67

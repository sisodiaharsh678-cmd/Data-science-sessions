# %%
TP = 50
TN = 120
FP = 10
FN = 20

accuracy  = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall    = TP / (TP + FN)
f1        = 2 * (precision * recall) / (precision + recall)

print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")
# Out:
# Accuracy  : 0.8500
# Precision : 0.8333
# Recall    : 0.7143
# F1 Score  : 0.7692

# %%
def print_confusion_matrix(tp, tn, fp, fn):
    print(f"{'':15}{'Predicted Pos':>15}{'Predicted Neg':>15}")
    print(f"{'Actual Pos':15}{tp:>15}{fn:>15}")
    print(f"{'Actual Neg':15}{fp:>15}{tn:>15}")

print_confusion_matrix(50, 120, 10, 20)
# Out:
#                  Predicted Pos  Predicted Neg
# Actual Pos                  50             20
# Actual Neg                  10            120

# %%
TP = 60
FN = 30
TN = 120
FP = 10

precision = TP / (TP + FP)
recall    = TP / (TP + FN)

print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
# Out:
# Precision: 0.8571
# Recall   : 0.6667

# %%
TP = 40
TN = 150
FP = 20
FN = 10

precision = TP / (TP + FP)
recall    = TP / (TP + FN)
f1        = 2 * (precision * recall) / (precision + recall)

print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Precision: 0.6667
# Recall   : 0.8000
# F1 Score : 0.7273

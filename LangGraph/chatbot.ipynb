# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

# %%
llm = init_chat_model("google_genai:gemini-3.6-flash")
llm.invoke("who is PM in india")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The current Prime Minister of India is **Narendra Modi**. He has been serving in this role since May 26, 2014, and began his third consecutive term in June 2024.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0701d-c778-7c52-9edf-d502578b72ce-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 243, 'total_tokens': 249, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 198}})

# %%
import numpy as np 
import matplotlib.pyplot as plt 

X = np.random.rand(10)
y = np.random.rand(10)

X , y
# Out:
# (array([0.51480035, 0.55730892, 0.82714571, 0.24997652, 0.62255847,
#         0.70848273, 0.06433557, 0.25067353, 0.26679789, 0.08645177]),
#  array([0.01644363, 0.49995066, 0.95572754, 0.38061141, 0.08957748,
#         0.13954219, 0.60139664, 0.86322539, 0.9536644 , 0.64624122]))

# %%
colors = np.random.rand(10)
sizes =  500*np.random.rand(10)
plt.scatter(X , y , c=colors , s=sizes)
plt.show()

# %%
a = ['a' , 'b' , 'c' , 'd' , 'e']
b = np.random.rand(5)
plt.barh(a,b)
# Out:
# <BarContainer object of 5 artists>

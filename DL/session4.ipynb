# %%
import math

def sigmoid(x):
    return 1 / (1 + math.exp(-x))

def tanh(x):
    return math.tanh(x)

def relu(x):
    return max(0, x)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 200)

sig = 1 / (1 + np.exp(-x))
tan = np.tanh(x)
rel = np.maximum(0, x)

plt.plot(x, sig, label='Sigmoid')
plt.plot(x, tan, label='Tanh')
plt.plot(x, rel, label='ReLU')
plt.legend()
plt.title('Activation Functions')
plt.grid(True)
plt.show()

# %%
import numpy as np

x = np.linspace(-10, 10, 20)
sig = 1 / (1 + np.exp(-x))
sig_derivative = sig * (1 - sig)

for xi, d in zip(x, sig_derivative):
    print(f"x={xi:.2f}, derivative={d:.6f}")
# Out:
# x=-10.00, derivative=0.000045
# x=-8.95, derivative=0.000130
# x=-7.89, derivative=0.000372
# x=-6.84, derivative=0.001066
# x=-5.79, derivative=0.003041
# x=-4.74, derivative=0.008615
# x=-3.68, derivative=0.023901
# x=-2.63, derivative=0.062627
# x=-1.58, derivative=0.141723
# x=-0.53, derivative=0.233456
# x=0.53, derivative=0.233456
# x=1.58, derivative=0.141723
# x=2.63, derivative=0.062627
# x=3.68, derivative=0.023901
# x=4.74, derivative=0.008615
# x=5.79, derivative=0.003041
# x=6.84, derivative=0.001066
# x=7.89, derivative=0.000372
# x=8.95, derivative=0.000130
# x=10.00, derivative=0.000045

# %%
import numpy as np 

def relu(x):
    return np.maximum(0 , x)

negative_inputs = np.array([-5, -3, 4, -0.5, -10])
outputs = relu(negative_inputs)

print("Inputs:", negative_inputs)
print("Outputs:", outputs)
# Out:
# Inputs: [ -5.   -3.    4.   -0.5 -10. ]
# Outputs: [0. 0. 4. 0. 0.]

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def scaled_sigmoid(x, a):
    return 1 / (1 + np.exp(-a * x))

x = np.linspace(-10, 10, 200)

plt.plot(x, sigmoid(x), label='Sigmoid (a=1)')
plt.plot(x, scaled_sigmoid(x, 3), label='Scaled Sigmoid (a=3)')
plt.legend()
plt.title('Sigmoid vs Scaled Sigmoid')
plt.grid(True)
plt.show()

# %%
import cv2

img = cv2.imread("/Users/harshsisodiya678/TOPS/Sessions/CV/Screenshot 2026-07-23 at 3.28.59 PM.png",cv2.IMREAD_GRAYSCALE)

#edges = cv2.Canny(image, threshold1, threshold2)
edges = cv2.Canny(img , 50 , 150)

cv2.imshow("original image" , img)
cv2.imshow("edges" , edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#threshholding

img = cv2.imread("/Users/harshsisodiya678/TOPS/Sessions/CV/Screenshot 2026-07-23 at 3.28.59 PM.png",cv2.IMREAD_GRAYSCALE)

retval, dst = cv2.threshold(src, thresh, maxval, type)

ret , thresh_img = cv2.threshold(img , 100 , 255 , cv2.THRESH_BINARY)

cv2.imshow("original image" , img)
cv2.imshow("thresh_img" , thresh_img)
cv2.waitKey(0)
cv2.destroyAllWindows()



""" 
90-0 black 
130-255 white 
180-255 white 
50-0 black

"""

# %%
#bitwise opration 

#combine image 
# cut out 
# flip / remove 

"""
1-cv2.bitwise_and(img1 , img2)
1-cv2.bitwise_or(img1 , img2)
1-cv2.bitwise_not(img1)
"""

import cv2
import numpy as np 

img1 = np.zeros((300,300) , dtype="uint8")
img2 = np.zeros((300,300) , dtype="uint8")

cv2.circle(img1 , (150,150) , 100 , 255 , -1)
cv2.rectangle(img2 , (100,100) , (250,250) , 255 , -1)

bitwise_and = cv2.bitwise_and(img1, img2)
bitwise_or = cv2.bitwise_or(img1, img2)
bitwise_not = cv2.bitwise_not(img1)

cv2.imshow("circle" , img1)
cv2.imshow("rectangle" , img2)
cv2.imshow("and" , bitwise_and)
cv2.imshow("or" , bitwise_or)
cv2.imshow("not" , bitwise_not)

# %% [markdown]
# ![image.png](attachment:image.png)

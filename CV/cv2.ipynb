# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        print("Failed to connect with camera")
        break

    cv2.imshow("camera", frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        print("Failed to connect with camera")
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 50)
    )

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    cv2.imshow("camera", frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ERROR:0@0.016] global persistence.cpp:584 open Can't open file: '/opt/anaconda3/envs/myenv/lib/python3.11/site-packages/cv2/data/haarcascade_frontalface_default.xml' in read mode
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 18
#      14     break
#      16 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# ---> 18 faces = face_cascade.detectMultiScale(
#      19     gray,
#      20     scaleFactor=1.1,
#      21     minNeighbors=5,
#      22     minSize=(30, 50)
#      23 )
#      25 for (x, y, w, h) in faces:
#      26     cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
#
# error: OpenCV(5.0.0) /Users/xperience/GHA-OpenCV-Python/_work/opencv-python/opencv-python/opencv_contrib/modules/xobjdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
import cv2


face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")


if face_cascade.empty():
    print("ERROR: Cascade file failed to load. Check the filename/path.")
else:
    print("Cascade loaded successfully.")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        print("Failed to connect with camera")
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 50)
    )

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    cv2.imshow("camera", frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Cascade loaded successfully.
